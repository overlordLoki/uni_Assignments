# %%
#imports
import numpy as np
import pandas as pd

# %%
class KNN:
    def __init__(self, k):
        self.k = k

    def fit(self, X, y):
        self.X = X
        self.y = y

    def predict(self, X):
        return [self._predict(x) for x in X]

# %%
import csv
#import the data
## Read the training and testing dataset
def read_data(filename):
    reader = csv.reader(open(filename), delimiter=" ")
    #csv to dataframe
    return pd.DataFrame(reader)

# %%
#assignment1_data\part1\wine-test is the test data
#read in the test data
data = read_data('assignment1_data\part1\wine-test')

# %%
data
# Out:
#          0           1     2                  3          4              5   \
# 0   Alcohol  Malic_acid   Ash  Alcalinity_of_ash  Magnesium  Total_phenols
# 1      12.7        3.55  2.36               21.5      106.0            1.7
# 2      12.2        3.03  2.32               19.0       96.0           1.25
# 3     14.13         4.1  2.74               24.5       96.0           2.05
# 4     13.05        1.65  2.55               18.0       98.0           2.45
# ..      ...         ...   ...                ...        ...            ...
# 85    11.84        0.89  2.58               18.0       94.0            2.2
# 86    13.73         1.5   2.7               22.5      101.0            3.0
# 87    13.39        1.77  2.62               16.1       93.0           2.85
# 88    11.62        1.99  2.28               18.0       98.0           3.02
# 89     13.9        1.68  2.12               16.0      101.0            3.1
#
# ...
